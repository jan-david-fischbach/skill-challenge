# %% [markdown]
# # Verify Euler
#
# > running a single 3d fdtd sim to verify the result of notebook 02

# %%
#| default_exp verify_euler

# %%
#| hide
from nbdev.showdoc import *

# %%
from skill_challenge.util import np, gf, gt, plt, nm

# %%
c = gf.components.bend_euler(angle=90, p=0.03961265779577252, radius=117.223)
c.plot()

# %%
try:
    gt.write_sparameters_1x1(c)
except Exception as e:
    print(e)
# Out:
# leveraging port_symmetries for 'o2'
# [16:10:49] ERROR: You do not have enough FlexCredits to run this simulation. You may be able  ]8;id=912843;file:///root/miniconda3/lib/python3.10/site-packages/tidy3d/web/http_management.py\http_management.py]8;;\:]8;id=20676;file:///root/miniconda3/lib/python3.10/site-packages/tidy3d/web/http_management.py#83\83]8;;\
#            to purchase or redeem more FlexCredits, or change your simulation plan from your
#            Account page.
# You do not have enough FlexCredits to run this simulation. You may be able to purchase or redeem more FlexCredits, or change your simulation plan from your Account page.

# %% [markdown]
# or maybe I don't... The computational cost is too large

# %%
#| hide
import nbdev; nbdev.nbdev_export()
